# %%
import pandas as pd
import numpy as np

paq = pd.read_sas("../data/PAQ_L.xpt")
demo = pd.read_sas("../data/DEMO_L.xpt")

df = paq.merge(demo, on="SEQN", how="left")

# %%
NHANES_MISSING = 5.397605e-79

df.replace(NHANES_MISSING, np.nan, inplace=True)
# Out:
#           SEQN       PAD790Q PAD790U  PAD800       PAD810Q PAD810U  PAD820  \
# 0     130378.0  3.000000e+00    b'W'    45.0  3.000000e+00    b'W'    45.0
# 1     130379.0  4.000000e+00    b'W'    45.0  3.000000e+00    b'W'    45.0
# 2     130380.0  1.000000e+00    b'W'    20.0  5.397605e-79     b''     NaN
# 3     130384.0  5.397605e-79     b''     NaN  5.397605e-79     b''     NaN
# 4     130385.0  1.000000e+00    b'D'    90.0  1.000000e+00    b'W'    60.0
# ...        ...           ...     ...     ...           ...     ...     ...
# 8148  142305.0  2.000000e+00    b'W'    40.0  5.397605e-79     b''     NaN
# 8149  142307.0  3.000000e+00    b'W'    15.0  5.397605e-79     b''     NaN
# 8150  142308.0  1.000000e+00    b'W'    45.0  5.397605e-79     b''     NaN
# 8151  142309.0  2.000000e+00    b'D'    15.0  5.397605e-79     b''     NaN
# 8152  142310.0  5.397605e-79     b''     NaN  5.397605e-79     b''     NaN
#
#       PAD680  SDDSRVYR  RIDSTATR  ...  DMDHRGND  DMDHRAGZ  DMDHREDZ  DMDHRMAZ  \
# 0      360.0      12.0       2.0  ...       NaN       NaN       NaN       NaN
# 1      480.0      12.0       2.0  ...       NaN       NaN       NaN       NaN
# 2      240.0      12.0       2.0  ...       NaN       NaN       NaN       NaN
# 3       60.0      12.0       1.0  ...       NaN       NaN       NaN       NaN
# 4      180.0      12.0       1.0  ...       NaN       NaN       NaN       NaN
# ...      ...       ...       ...  ...       ...       ...       ...       ...
# 8148   480.0      12.0       2.0  ...       NaN       NaN       NaN       NaN
# 8149   480.0      12.0       2.0  ...       NaN       NaN       NaN       NaN
# 8150   600.0      12.0       2.0  ...       NaN       NaN       NaN       NaN
# 8151   240.0      12.0       2.0  ...       NaN       NaN       NaN       NaN
# 8152   360.0      12.0       2.0  ...       NaN       NaN       NaN       NaN
#
#       DMDHSEDZ      WTINT2YR      WTMEC2YR  SDMVSTRA  SDMVPSU  INDFMPIR
# 0          NaN  50055.450807  5.437446e+04     173.0      2.0      5.00
# 1          NaN  29087.450605  3.408472e+04     173.0      2.0      5.00
# 2          NaN  80062.674301  8.119628e+04     174.0      1.0      1.41
# 3          NaN  15078.746749  5.397605e-79     179.0      2.0      0.63
# 4          NaN  16151.033173  5.397605e-79     187.0      2.0      5.00
# ...        ...           ...           ...       ...      ...       ...
# 8148       NaN  28979.979165  4.348341e+04     180.0      2.0      2.25
# 8149       NaN  69419.620456  6.496233e+04     181.0      1.0       NaN
# 8150       NaN  32696.313477  4.436753e+04     183.0      2.0      1.95
# 8151       NaN  30547.974564  4.624936e+04     176.0      1.0      3.11
# 8152       NaN  32753.585494  4.964723e+04     187.0      2.0      5.00
#
# [8153 rows x 34 columns]

# %%
def decode_unit(x):
    if isinstance(x, bytes):
        return x.decode("utf-8")
    return np.nan

df["PAD790U"] = df["PAD790U"].apply(decode_unit)
df["PAD810U"] = df["PAD810U"].apply(decode_unit)

# %%
UNIT_TO_WEEK = {
    "D": 7,
    "W": 1,
    "M": 1/4.33,
    "Y": 1/52
}

def weekly_minutes(freq, unit, mins):
    if pd.isna(freq) or pd.isna(unit) or pd.isna(mins):
        return np.nan
    mult = UNIT_TO_WEEK.get(unit)
    if mult is None:
        return np.nan
    return freq * mins * mult

df["moderate_min_week"] = df.apply(
    lambda r: weekly_minutes(r["PAD790Q"], r["PAD790U"], r["PAD800"]),
    axis=1
)

df["vigorous_min_week"] = df.apply(
    lambda r: weekly_minutes(r["PAD810Q"], r["PAD810U"], r["PAD820"]),
    axis=1
)

# %%
df["mvpa_equiv_min_week"] = (
    df["moderate_min_week"] + 2 * df["vigorous_min_week"]
)

# %%
df["sedentary_hours_day"] = df["PAD680"] / 60
df.loc[df["sedentary_hours_day"] > 16, "sedentary_hours_day"] = np.nan

# %%
df_clean = df.rename(columns={
    "SEQN": "seqn",
    "RIDAGEYR": "age",
    "RIAGENDR": "sex"
})

# %%
df_clean = df_clean[
    [
        "seqn",
        "age",
        "sex",
        "moderate_min_week",
        "vigorous_min_week",
        "mvpa_equiv_min_week",
        "sedentary_hours_day"
    ]
]

# %%
df_clean.describe()
df_clean.isna().mean()
# Out:
# seqn                   0.000000
# age                    0.000000
# sex                    0.000000
# moderate_min_week      0.216239
# vigorous_min_week      0.547896
# mvpa_equiv_min_week    0.560039
# sedentary_hours_day    0.016926
# dtype: float64

# %%
df_clean.to_csv("../data/paq_activity_clean.csv", index=False)
print("Saved: data/paq_activity_clean.csv")
# Out:
# Saved: data/paq_activity_clean.csv
